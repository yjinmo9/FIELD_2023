# %% [markdown]
# ### Before Russia (R,Q)=(42,68)

# %%
import numpy as np
import pandas as pd
from IPython.display import clear_output

clear_output
def simulation(period):
    cost = 0
    country_list={'before':{'USA':[8,1.5],'Saudi':[6,0.5],'Russia':[5,0.5]},'after':{'USA':[8,2],'Saudi':[6,1.5],'Russia':[7,4]}}
    cost_list = [0]
    #참가자들이 직접 입력하시면 됩니다. / 1 period = 5일, 6 period = 한 달 로 진행됩니다.
    oil_price_list = {'before':{'USA':[59.442322,61.105856, 62.034866,62.634655,63.086882],'Saudi':[65.594224, 68.084713, 69.651625,70.809178,71.78529],'Russia':[66.114746,67.980426,68.981097,69.574907,69.97735]},'after':{'USA':[98.498265, 101.457225, 103.692719, 105.831811, 107.958056],'Saudi':[100.970904,104.6987,107.070433,108.964912,110.691427],'Russia':[96.112196,98.470851,100.355018,102.067786,103.71864]}}
    oil_price_print=[]
    demand = [7] * period
    inventory = [100]
    order = []
    user_order=0
    order_time=[0] * period
    arrival_time=['-'] * period
    lead_time=['-'] * period

    print("시뮬레이션에 오신 걸 환영합니다!")
    print("전쟁 전인가요 후인가요?")
    print("before / after 중에 선택해주세요")
    war=input()
    while (war != "before" and war != "after"):
        war = input()
    if war=='before' :
        inventory_cost = 8
    else :
        inventory_cost = 10
    print("나라를 선택해주세요")
    print("USA / Saudi / Russia 중에 선택해주세요")
    coun = input()
    while (coun != "USA" and coun != "Saudi" and coun !="Russia"):
        coun = input()
    lead_mean, lead_std=country_list[war][coun]
    for i in range(period):
        oil_price=oil_price_list[war][coun][int(i/6)]
        print("<Period %i>" %i)
        oil_price_print.append(oil_price)
        for sample_period, order_amount in order:
            if sample_period <= i:
                print("주문이 도착했습니다!!")
                inventory[i] += order_amount
                order.pop(0)
        print("현재 석유 가격: {}".format(oil_price))
        print("현재 수요: %i" %demand[i])
        print("현재 보관량: %i" %inventory[i])
        print("현재 비용: {}" .format(cost))

        while True:
            print("행동을 선택하세요!")
            print("[O] 주문")
            print("[N] 다음 Period로")
            user = input()
            while (user != "O" and user != "N"):
                user = input()
            if user == "O":
                print("얼마나 주문하실 건가요?")
                while True:
                    user_order = input()
                    try:
                        user_order = int(user_order)
                        print("%i를 주문했습니다!" %user_order)
                        cost += user_order * oil_price
                        order_time[i] = 1
                        arrival= i + np.random.normal(lead_mean,lead_std,1)
                        lead_time[i]=int(arrival[0])+1-i
                        arrival_time[i] = int(arrival[0])+1
                        order.append((arrival_time[i], user_order))
                        break
                    except:
                        continue

            print("================================")
            break
        if inventory[i]>0 :
            cost += (inventory[i]) * inventory_cost
        else :
            cost -= (inventory[i]) * (3 * oil_price)

        inventory.append(inventory[i] - demand[i])
        cost_list.append(cost)
    result = pd.DataFrame([oil_price_print, demand, inventory, cost_list,order_time,lead_time,arrival_time], index = ["Oil Price","Demand", "Inventory", "Cost","Order","Lead Time", "Arrival"])

    result.to_csv("결과.csv")
simulation(25)
# Out:
# 시뮬레이션에 오신 걸 환영합니다!
# 전쟁 전인가요 후인가요?
# before / after 중에 선택해주세요
# before
# 나라를 선택해주세요
# USA / Saudi / Russia 중에 선택해주세요
# Russia
# <Period 0>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 100
# 현재 비용: 0
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 1>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 93
# 현재 비용: 800
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 2>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 86
# 현재 비용: 1544
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 3>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 79
# 현재 비용: 2232
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 4>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 72
# 현재 비용: 2864
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 5>
# 현재 석유 가격: 66.114746
# 현재 수요: 7
# 현재 보관량: 65
# 현재 비용: 3440
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 6>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 58
# 현재 비용: 3960
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 7>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 51
# 현재 비용: 4424
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 8>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 44
# 현재 비용: 4832
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 9>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 37
# 현재 비용: 5184
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# O
# 얼마나 주문하실 건가요?
# 68
# 68를 주문했습니다!
# ================================
# <Period 10>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 30
# 현재 비용: 10102.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 11>
# 현재 석유 가격: 67.980426
# 현재 수요: 7
# 현재 보관량: 23
# 현재 비용: 10342.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 12>
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 16
# 현재 비용: 10526.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 13>
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 9
# 현재 비용: 10654.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 14>
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 2
# 현재 비용: 10726.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 15>
# 주문이 도착했습니다!!
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 63
# 현재 비용: 10742.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 16>
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 56
# 현재 비용: 11246.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 17>
# 현재 석유 가격: 68.981097
# 현재 수요: 7
# 현재 보관량: 49
# 현재 비용: 11694.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 18>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 42
# 현재 비용: 12086.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 19>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 35
# 현재 비용: 12422.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 20>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 28
# 현재 비용: 12702.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 21>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 21
# 현재 비용: 12926.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 22>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 14
# 현재 비용: 13094.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 23>
# 현재 석유 가격: 69.574907
# 현재 수요: 7
# 현재 보관량: 7
# 현재 비용: 13206.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 24>
# 현재 석유 가격: 69.97735
# 현재 수요: 7
# 현재 보관량: 0
# 현재 비용: 13262.668968
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================

# %% [markdown]
# ### After Russia Best

# %%
import numpy as np
import pandas as pd
from IPython.display import clear_output

clear_output
def simulation(period):
    cost = 0
    country_list={'before':{'USA':[8,1.5],'Saudi':[6,0.5],'Russia':[5,0.5]},'after':{'USA':[8,2],'Saudi':[6,1.5],'Russia':[7,4]}}
    cost_list = [0]
    #참가자들이 직접 입력하시면 됩니다. / 1 period = 5일, 6 period = 한 달 로 진행됩니다.
    oil_price_list = {'before':{'USA':[59.442322,61.105856, 62.034866,62.634655,63.086882],'Saudi':[65.594224, 68.084713, 69.651625,70.809178,71.78529],'Russia':[66.114746,67.980426,68.981097,69.574907,69.97735]},'after':{'USA':[98.498265, 101.457225, 103.692719, 105.831811, 107.958056],'Saudi':[100.970904,104.6987,107.070433,108.964912,110.691427],'Russia':[96.112196,98.470851,100.355018,102.067786,103.71864]}}
    oil_price_print=[]
    demand = [7] * period
    inventory = [100]
    order = []
    user_order=0
    order_time=[0] * period
    arrival_time=['-'] * period
    lead_time=['-'] * period

    print("시뮬레이션에 오신 걸 환영합니다!")
    print("전쟁 전인가요 후인가요?")
    print("before / after 중에 선택해주세요")
    war=input()
    while (war != "before" and war != "after"):
        war = input()
    if war=='before' :
        inventory_cost = 8
    else :
        inventory_cost = 10
    print("나라를 선택해주세요")
    print("USA / Saudi / Russia 중에 선택해주세요")
    coun = input()
    while (coun != "USA" and coun != "Saudi" and coun !="Russia"):
        coun = input()
    lead_mean, lead_std=country_list[war][coun]
    for i in range(period):
        oil_price=oil_price_list[war][coun][int(i/6)]
        print("<Period %i>" %i)
        oil_price_print.append(oil_price)
        for sample_period, order_amount in order:
            if sample_period <= i:
                print("주문이 도착했습니다!!")
                inventory[i] += order_amount
                order.pop(0)
        print("현재 석유 가격: {}".format(oil_price))
        print("현재 수요: %i" %demand[i])
        print("현재 보관량: %i" %inventory[i])
        print("현재 비용: {}" .format(cost))

        while True:
            print("행동을 선택하세요!")
            print("[O] 주문")
            print("[N] 다음 Period로")
            user = input()
            while (user != "O" and user != "N"):
                user = input()
            if user == "O":
                print("얼마나 주문하실 건가요?")
                while True:
                    user_order = input()
                    try:
                        user_order = int(user_order)
                        print("%i를 주문했습니다!" %user_order)
                        cost += user_order * oil_price
                        order_time[i] = 1
                        arrival= i + np.random.normal(lead_mean,lead_std,1)
                        lead_time[i]=int(arrival[0])+1-i
                        arrival_time[i] = int(arrival[0])+1
                        order.append((arrival_time[i], user_order))
                        break
                    except:
                        continue

            print("================================")
            break
        if inventory[i]>0 :
            cost += (inventory[i]) * inventory_cost
        else :
            cost -= (inventory[i]) * (3 * oil_price)

        inventory.append(inventory[i] - demand[i])
        cost_list.append(cost)
    result = pd.DataFrame([oil_price_print, demand, inventory, cost_list,order_time,lead_time,arrival_time], index = ["Oil Price","Demand", "Inventory", "Cost","Order","Lead Time", "Arrival"])

    result.to_csv("결과.csv")
simulation(25)
# Out:
# 시뮬레이션에 오신 걸 환영합니다!
# 전쟁 전인가요 후인가요?
# before / after 중에 선택해주세요
# after
# 나라를 선택해주세요
# USA / Saudi / Russia 중에 선택해주세요
# Russia
# <Period 0>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 100
# 현재 비용: 0
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 1>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 93
# 현재 비용: 1000
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 2>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 86
# 현재 비용: 1930
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 3>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 79
# 현재 비용: 2790
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 4>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 72
# 현재 비용: 3580
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 5>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 65
# 현재 비용: 4300
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 6>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 58
# 현재 비용: 4950
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 7>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 51
# 현재 비용: 5530
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 8>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 44
# 현재 비용: 6040
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 9>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 37
# 현재 비용: 6480
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# O
# 얼마나 주문하실 건가요?
# 68
# 68를 주문했습니다!
# ================================
# <Period 10>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 30
# 현재 비용: 13546.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 11>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 23
# 현재 비용: 13846.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 12>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 16
# 현재 비용: 14076.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 13>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 9
# 현재 비용: 14236.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 14>
# 주문이 도착했습니다!!
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 70
# 현재 비용: 14326.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 15>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 63
# 현재 비용: 15026.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 16>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 56
# 현재 비용: 15656.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 17>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 49
# 현재 비용: 16216.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 18>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 42
# 현재 비용: 16706.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 19>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 35
# 현재 비용: 17126.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 20>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 28
# 현재 비용: 17476.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 21>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 21
# 현재 비용: 17756.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 22>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 14
# 현재 비용: 17966.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 23>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 7
# 현재 비용: 18106.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 24>
# 현재 석유 가격: 103.71864
# 현재 수요: 7
# 현재 보관량: 0
# 현재 비용: 18176.017868
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================

# %% [markdown]
# ### After Russia worst

# %%
import numpy as np
import pandas as pd
from IPython.display import clear_output

clear_output
def simulation(period):
    cost = 0
    country_list={'before':{'USA':[8,1.5],'Saudi':[6,0.5],'Russia':[5,0.5]},'after':{'USA':[8,2],'Saudi':[6,1.5],'Russia':[7,4]}}
    cost_list = [0]
    #참가자들이 직접 입력하시면 됩니다. / 1 period = 5일, 6 period = 한 달 로 진행됩니다.
    oil_price_list = {'before':{'USA':[59.442322,61.105856, 62.034866,62.634655,63.086882],'Saudi':[65.594224, 68.084713, 69.651625,70.809178,71.78529],'Russia':[66.114746,67.980426,68.981097,69.574907,69.97735]},'after':{'USA':[98.498265, 101.457225, 103.692719, 105.831811, 107.958056],'Saudi':[100.970904,104.6987,107.070433,108.964912,110.691427],'Russia':[96.112196,98.470851,100.355018,102.067786,103.71864]}}
    oil_price_print=[]
    demand = [7] * period
    inventory = [100]
    order = []
    user_order=0
    order_time=[0] * period
    arrival_time=['-'] * period
    lead_time=['-'] * period

    print("시뮬레이션에 오신 걸 환영합니다!")
    print("전쟁 전인가요 후인가요?")
    print("before / after 중에 선택해주세요")
    war=input()
    while (war != "before" and war != "after"):
        war = input()
    if war=='before' :
        inventory_cost = 8
    else :
        inventory_cost = 10
    print("나라를 선택해주세요")
    print("USA / Saudi / Russia 중에 선택해주세요")
    coun = input()
    while (coun != "USA" and coun != "Saudi" and coun !="Russia"):
        coun = input()
    lead_mean, lead_std=country_list[war][coun]
    for i in range(period):
        oil_price=oil_price_list[war][coun][int(i/6)]
        print("<Period %i>" %i)
        oil_price_print.append(oil_price)
        for sample_period, order_amount in order:
            if sample_period <= i:
                print("주문이 도착했습니다!!")
                inventory[i] += order_amount
                order.pop(0)
        print("현재 석유 가격: {}".format(oil_price))
        print("현재 수요: %i" %demand[i])
        print("현재 보관량: %i" %inventory[i])
        print("현재 비용: {}" .format(cost))

        while True:
            print("행동을 선택하세요!")
            print("[O] 주문")
            print("[N] 다음 Period로")
            user = input()
            while (user != "O" and user != "N"):
                user = input()
            if user == "O":
                print("얼마나 주문하실 건가요?")
                while True:
                    user_order = input()
                    try:
                        user_order = int(user_order)
                        print("%i를 주문했습니다!" %user_order)
                        cost += user_order * oil_price
                        order_time[i] = 1
                        arrival= i + np.random.normal(lead_mean,lead_std,1)
                        lead_time[i]=int(arrival[0])+1-i
                        arrival_time[i] = int(arrival[0])+1
                        order.append((arrival_time[i], user_order))
                        break
                    except:
                        continue

            print("================================")
            break
        if inventory[i]>0 :
            cost += (inventory[i]) * inventory_cost
        else :
            cost -= (inventory[i]) * (3 * oil_price)

        inventory.append(inventory[i] - demand[i])
        cost_list.append(cost)
    result = pd.DataFrame([oil_price_print, demand, inventory, cost_list,order_time,lead_time,arrival_time], index = ["Oil Price","Demand", "Inventory", "Cost","Order","Lead Time", "Arrival"])

    result.to_csv("결과.csv")
simulation(25)
# Out:
# 시뮬레이션에 오신 걸 환영합니다!
# 전쟁 전인가요 후인가요?
# before / after 중에 선택해주세요
# after
# 나라를 선택해주세요
# USA / Saudi / Russia 중에 선택해주세요
# Russia
# <Period 0>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 100
# 현재 비용: 0
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 1>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 93
# 현재 비용: 1000
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 2>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 86
# 현재 비용: 1930
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 3>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 79
# 현재 비용: 2790
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 4>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 72
# 현재 비용: 3580
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 5>
# 현재 석유 가격: 96.112196
# 현재 수요: 7
# 현재 보관량: 65
# 현재 비용: 4300
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 6>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 58
# 현재 비용: 4950
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 7>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 51
# 현재 비용: 5530
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 8>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 44
# 현재 비용: 6040
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 9>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 37
# 현재 비용: 6480
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# O
# 얼마나 주문하실 건가요?
# 68
# 68를 주문했습니다!
# ================================
# <Period 10>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 30
# 현재 비용: 13546.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 11>
# 현재 석유 가격: 98.470851
# 현재 수요: 7
# 현재 보관량: 23
# 현재 비용: 13846.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 12>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 16
# 현재 비용: 14076.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 13>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 9
# 현재 비용: 14236.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 14>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: 2
# 현재 비용: 14326.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 15>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: -5
# 현재 비용: 14346.017867999999
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 16>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: -12
# 현재 비용: 15851.343138
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 17>
# 현재 석유 가격: 100.355018
# 현재 수요: 7
# 현재 보관량: -19
# 현재 비용: 19464.123786
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 18>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: -26
# 현재 비용: 25184.359812000002
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 19>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: -33
# 현재 비용: 33145.64712
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 20>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: -40
# 현재 비용: 43250.357934
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 21>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: -47
# 현재 비용: 55498.492254
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 22>
# 주문이 도착했습니다!!
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 14
# 현재 비용: 69890.05008
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 23>
# 현재 석유 가격: 102.067786
# 현재 수요: 7
# 현재 보관량: 7
# 현재 비용: 70030.05008
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 24>
# 현재 석유 가격: 103.71864
# 현재 수요: 7
# 현재 보관량: 0
# 현재 비용: 70100.05008
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================

# %% [markdown]
# ### after saudi

# %%
import numpy as np
import pandas as pd
from IPython.display import clear_output

clear_output
def simulation(period):
    cost = 0
    country_list={'before':{'USA':[8,1.5],'Saudi':[6,0.5],'Russia':[5,0.5]},'after':{'USA':[8,2],'Saudi':[6,1.5],'Russia':[7,4]}}
    cost_list = [0]
    #참가자들이 직접 입력하시면 됩니다. / 1 period = 5일, 6 period = 한 달 로 진행됩니다.
    oil_price_list = {'before':{'USA':[59.442322,61.105856, 62.034866,62.634655,63.086882],'Saudi':[65.594224, 68.084713, 69.651625,70.809178,71.78529],'Russia':[66.114746,67.980426,68.981097,69.574907,69.97735]},'after':{'USA':[98.498265, 101.457225, 103.692719, 105.831811, 107.958056],'Saudi':[100.970904,104.6987,107.070433,108.964912,110.691427],'Russia':[96.112196,98.470851,100.355018,102.067786,103.71864]}}
    oil_price_print=[]
    demand = [7] * period
    inventory = [100]
    order = []
    user_order=0
    order_time=[0] * period
    arrival_time=['-'] * period
    lead_time=['-'] * period

    print("시뮬레이션에 오신 걸 환영합니다!")
    print("전쟁 전인가요 후인가요?")
    print("before / after 중에 선택해주세요")
    war=input()
    while (war != "before" and war != "after"):
        war = input()
    if war=='before' :
        inventory_cost = 8
    else :
        inventory_cost = 10
    print("나라를 선택해주세요")
    print("USA / Saudi / Russia 중에 선택해주세요")
    coun = input()
    while (coun != "USA" and coun != "Saudi" and coun !="Russia"):
        coun = input()
    lead_mean, lead_std=country_list[war][coun]
    for i in range(period):
        oil_price=oil_price_list[war][coun][int(i/6)]
        print("<Period %i>" %i)
        oil_price_print.append(oil_price)
        for sample_period, order_amount in order:
            if sample_period <= i:
                print("주문이 도착했습니다!!")
                inventory[i] += order_amount
                order.pop(0)
        print("현재 석유 가격: {}".format(oil_price))
        print("현재 수요: %i" %demand[i])
        print("현재 보관량: %i" %inventory[i])
        print("현재 비용: {}" .format(cost))

        while True:
            print("행동을 선택하세요!")
            print("[O] 주문")
            print("[N] 다음 Period로")
            user = input()
            while (user != "O" and user != "N"):
                user = input()
            if user == "O":
                print("얼마나 주문하실 건가요?")
                while True:
                    user_order = input()
                    try:
                        user_order = int(user_order)
                        print("%i를 주문했습니다!" %user_order)
                        cost += user_order * oil_price
                        order_time[i] = 1
                        arrival= i + np.random.normal(lead_mean,lead_std,1)
                        lead_time[i]=int(arrival[0])+1-i
                        arrival_time[i] = int(arrival[0])+1
                        order.append((arrival_time[i], user_order))
                        break
                    except:
                        continue

            print("================================")
            break
        if inventory[i]>0 :
            cost += (inventory[i]) * inventory_cost
        else :
            cost -= (inventory[i]) * (3 * oil_price)

        inventory.append(inventory[i] - demand[i])
        cost_list.append(cost)
    result = pd.DataFrame([oil_price_print, demand, inventory, cost_list,order_time,lead_time,arrival_time], index = ["Oil Price","Demand", "Inventory", "Cost","Order","Lead Time", "Arrival"])

    result.to_csv("결과.csv")
simulation(25)
# Out:
# 시뮬레이션에 오신 걸 환영합니다!
# 전쟁 전인가요 후인가요?
# before / after 중에 선택해주세요
# after
# 나라를 선택해주세요
# USA / Saudi / Russia 중에 선택해주세요
# Saudi
# <Period 0>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 100
# 현재 비용: 0
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 1>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 93
# 현재 비용: 1000
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 2>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 86
# 현재 비용: 1930
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 3>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 79
# 현재 비용: 2790
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 4>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 72
# 현재 비용: 3580
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 5>
# 현재 석유 가격: 100.970904
# 현재 수요: 7
# 현재 보관량: 65
# 현재 비용: 4300
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 6>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 58
# 현재 비용: 4950
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 7>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 51
# 현재 비용: 5530
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 8>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 44
# 현재 비용: 6040
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 9>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 37
# 현재 비용: 6480
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# O
# 얼마나 주문하실 건가요?
# 68
# 68를 주문했습니다!
# ================================
# <Period 10>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 30
# 현재 비용: 13969.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 11>
# 현재 석유 가격: 104.6987
# 현재 수요: 7
# 현재 보관량: 23
# 현재 비용: 14269.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 12>
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 16
# 현재 비용: 14499.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 13>
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 9
# 현재 비용: 14659.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 14>
# 주문이 도착했습니다!!
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 70
# 현재 비용: 14749.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 15>
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 63
# 현재 비용: 15449.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 16>
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 56
# 현재 비용: 16079.5116
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 17>
# 현재 석유 가격: 107.070433
# 현재 수요: 7
# 현재 보관량: 49
# 현재 비용: 16639.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 18>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 42
# 현재 비용: 17129.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 19>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 35
# 현재 비용: 17549.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 20>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 28
# 현재 비용: 17899.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 21>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 21
# 현재 비용: 18179.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 22>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 14
# 현재 비용: 18389.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 23>
# 현재 석유 가격: 108.964912
# 현재 수요: 7
# 현재 보관량: 7
# 현재 비용: 18529.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
# <Period 24>
# 현재 석유 가격: 110.691427
# 현재 수요: 7
# 현재 보관량: 0
# 현재 비용: 18599.511599999998
# 행동을 선택하세요!
# [O] 주문
# [N] 다음 Period로
# N
# ================================
